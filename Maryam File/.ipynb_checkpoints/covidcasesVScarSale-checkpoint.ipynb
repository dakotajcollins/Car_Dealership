# %%
 import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as py
import time
from datetime import datetime

# %%
covid_file = "../CSV/covid_us_county.csv"
population_file="../CSV/US_population.csv"

covid_df = pd.read_csv(covid_file)

population_df=pd.read_csv(population_file)

covid_df
# Out:
#             fips   county    state        lat        long        date  cases  \
# 0         1001.0  Autauga  Alabama  32.539527  -86.644082  2020-01-22      0
# 1         1001.0  Autauga  Alabama  32.539527  -86.644082  2020-01-23      0
# 2         1001.0  Autauga  Alabama  32.539527  -86.644082  2020-01-24      0
# 3         1001.0  Autauga  Alabama  32.539527  -86.644082  2020-01-25      0
# 4         1001.0  Autauga  Alabama  32.539527  -86.644082  2020-01-26      0
# ...          ...      ...      ...        ...         ...         ...    ...
# 1834753  56045.0   Weston  Wyoming  43.839612 -104.567488  2021-07-18    664
# 1834754  56045.0   Weston  Wyoming  43.839612 -104.567488  2021-07-19    665
# 1834755  56045.0   Weston  Wyoming  43.839612 -104.567488  2021-07-21    669
# 1834756  56045.0   Weston  Wyoming  43.839612 -104.567488  2021-07-22    670
# 1834757  56045.0   Weston  Wyoming  43.839612 -104.567488  2021-07-23    672
#
#         state_code  deaths
# 0               AL       0
# 1               AL       0
# 2               AL       0
# 3               AL       0
# 4               AL       0
# ...            ...     ...
# 1834753         WY       6
# 1834754         WY       6
# 1834755         WY       6
# 1834756         WY       6
# 1834757         WY       6
#
# [1834758 rows x 9 columns]

# %%
case = covid_df.groupby(["state"]).max()["cases"]
mean_state=covid_df.groupby(["state"]).mean()["cases"]

covid_by_state=pd.DataFrame({"Cases":case,
                             "Mean" :mean_state}).reset_index()
covid_by_state
# Out:
#                        state    Cases          Mean
# 0                    Alabama    83039   3587.029276
# 1                     Alaska    32413    874.319037
# 2             American Samoa        0      0.000000
# 3                    Arizona   573082  23094.614915
# 4                   Arkansas    44983   2001.059092
# 5                 California  1276254  27537.130389
# 6                   Colorado    75412   3331.617100
# 7                Connecticut   101119  14530.079781
# 8                   Delaware    65530   8946.099818
# 9           Diamond Princess       49     44.080146
# 10      District of Columbia    49973   7645.292046
# 11                   Florida   533821  14784.461551
# 12                   Georgia   104836   3118.744595
# 13            Grand Princess      103     91.163934
# 14                      Guam     8501   4066.635701
# 15                    Hawaii    29333   2255.389539
# 16                     Idaho    54649   1869.651818
# 17                  Illinois   561168   5948.135526
# 18                   Indiana   104970   3416.759001
# 19                      Iowa    58891   1705.251565
# 20                    Kansas    61987   1312.727338
# 21                  Kentucky    84173   1549.541103
# 22                 Louisiana    50084   3455.198322
# 23                     Maine    17400   1273.068610
# 24                  Maryland    86175   7928.063752
# 25             Massachusetts   136324  17692.140148
# 26                  Michigan   167250   4351.098800
# 27                 Minnesota   126249   2850.735535
# 28               Mississippi    22901   1770.382622
# 29                  Missouri   105603   2318.069016
# 30                   Montana    18348    825.462911
# 31                  Nebraska    71755   1070.415281
# 32                    Nevada   273860   7710.845844
# 33             New Hampshire    36590   3028.955981
# 34                New Jersey   105835  19032.171379
# 35                New Mexico    60017   2520.016862
# 36                  New York   284750  14159.623577
# 37            North Carolina   116949   4110.567002
# 38              North Dakota    24854    925.549627
# 39  Northern Mariana Islands      183     87.395264
# 40                      Ohio   130071   5083.440275
# 41                  Oklahoma    88919   2486.946923
# 42                    Oregon    41288   2100.854089
# 43              Pennsylvania   155859   6878.735593
# 44               Puerto Rico    18780    664.103165
# 45              Rhode Island    99884   9130.723393
# 46            South Carolina    76419   5241.508121
# 47              South Dakota    31851    834.806172
# 48                 Tennessee   101819   3920.487071
# 49                     Texas   411554   5101.147143
# 50                      Utah   157373   4818.873037
# 51                   Vermont     7641    507.333903
# 52            Virgin Islands     4336   1526.236794
# 53                  Virginia    77838   2106.294907
# 54                Washington   115189   4394.615665
# 55             West Virginia    15594   1079.638449
# 56                 Wisconsin   119166   4118.084010
# 57                   Wyoming    11338   1031.054936

# %%
merge_df = pd.merge(covid_by_state , population_df, on="state")

merge_df["Infection Rate"]=(merge_df["Cases"]/merge_df["Population"]*100)

merge_df.sort_values('Infection Rate', ascending=False)
                             
#merge_df.to_csv("../CSV/Infection_rate.csv" )
# Out:
#                    state    Cases          Mean  Population  Infection Rate
# 40          Rhode Island    99884   9130.723393     1059361        9.428703
# 28                Nevada   273860   7710.845844     3080156        8.891108
# 2                Arizona   573082  23094.614915     7278717        7.873393
# 8   District of Columbia    49973   7645.292046      705749        7.080846
# 7               Delaware    65530   8946.099818      973764        6.729557
# 45                  Utah   157373   4818.873037     3205958        4.908767
# 1                 Alaska    32413    874.319037      731545        4.430760
# 13              Illinois   561168   5948.135526    12671821        4.428472
# 27              Nebraska    71755   1070.415281     1934408        3.709404
# 42          South Dakota    31851    834.806172      884659        3.600370
# 34          North Dakota    24854    925.549627      762062        3.261414
# 4             California  1276254  27537.130389    39512223        3.230023
# 12                 Idaho    54649   1869.651818     1787065        3.058031
# 31            New Mexico    60017   2520.016862     2096829        2.862274
# 6            Connecticut   101119  14530.079781     3565287        2.836209
# 29         New Hampshire    36590   3028.955981     1359711        2.691013
# 9                Florida   533821  14784.461551    21477737        2.485462
# 36              Oklahoma    88919   2486.946923     3956971        2.247148
# 23             Minnesota   126249   2850.735535     5639632        2.238604
# 16                Kansas    61987   1312.727338     2913314        2.127714
# 11                Hawaii    29333   2255.389539     1415872        2.071727
# 50             Wisconsin   119166   4118.084010     5822434        2.046670
# 21         Massachusetts   136324  17692.140148     6892503        1.977859
# 51               Wyoming    11338   1031.054936      578759        1.959019
# 17              Kentucky    84173   1549.541103     4467673        1.884046
# 15                  Iowa    58891   1705.251565     3155070        1.866551
# 25              Missouri   105603   2318.069016     6137428        1.720639
# 26               Montana    18348    825.462911     1068778        1.716727
# 0                Alabama    83039   3587.029276     4903185        1.693573
# 22              Michigan   167250   4351.098800     9986857        1.674701
# 14               Indiana   104970   3416.759001     6732219        1.559218
# 48            Washington   115189   4394.615665     7614893        1.512680
# 43             Tennessee   101819   3920.487071     6829174        1.490942
# 3               Arkansas    44983   2001.059092     3017804        1.490587
# 41        South Carolina    76419   5241.508121     5148714        1.484235
# 32              New York   284750  14159.623577    19453561        1.463742
# 20              Maryland    86175   7928.063752     6045680        1.425398
# 44                 Texas   411554   5101.147143    28995881        1.419353
# 5               Colorado    75412   3331.617100     5758736        1.309523
# 19                 Maine    17400   1273.068610     1344212        1.294439
# 46               Vermont     7641    507.333903      623989        1.224541
# 38          Pennsylvania   155859   6878.735593    12801989        1.217459
# 30            New Jersey   105835  19032.171379     8882190        1.191542
# 33        North Carolina   116949   4110.567002    10488084        1.115065
# 35                  Ohio   130071   5083.440275    11689100        1.112755
# 18             Louisiana    50084   3455.198322     4648794        1.077355
# 10               Georgia   104836   3118.744595    10617423        0.987396
# 37                Oregon    41288   2100.854089     4217737        0.978914
# 47              Virginia    77838   2106.294907     8535519        0.911930
# 49         West Virginia    15594   1079.638449     1792147        0.870130
# 24           Mississippi    22901   1770.382622     2976149        0.769484
# 39           Puerto Rico    18780    664.103165     3193694        0.588034

# %%
#group by month

covid_df.index = pd.to_datetime(covid_df['date'])
                                #format='%y-%m-%d %I:%M%p')
covid_df.groupby(by=[covid_df.index.month, covid_df.index.year])
covid_df.head()
# Out:
#               fips   county    state        lat       long        date  cases  \
# date
# 2020-01-22  1001.0  Autauga  Alabama  32.539527 -86.644082  2020-01-22      0
# 2020-01-23  1001.0  Autauga  Alabama  32.539527 -86.644082  2020-01-23      0
# 2020-01-24  1001.0  Autauga  Alabama  32.539527 -86.644082  2020-01-24      0
# 2020-01-25  1001.0  Autauga  Alabama  32.539527 -86.644082  2020-01-25      0
# 2020-01-26  1001.0  Autauga  Alabama  32.539527 -86.644082  2020-01-26      0
#
#            state_code  deaths
# date
# 2020-01-22         AL       0
# 2020-01-23         AL       0
# 2020-01-24         AL       0
# 2020-01-25         AL       0
# 2020-01-26         AL       0

# %%
#seprating date value
covid_df['day'] = covid_df.index.day
covid_df['month'] = covid_df.index.month
covid_df['year'] = covid_df.index.year
covid_df
# Out:
#               fips   county    state        lat       long        date  cases  \
# date
# 2020-01-22  1001.0  Autauga  Alabama  32.539527 -86.644082  2020-01-22      0
# 2020-01-23  1001.0  Autauga  Alabama  32.539527 -86.644082  2020-01-23      0
# 2020-01-24  1001.0  Autauga  Alabama  32.539527 -86.644082  2020-01-24      0
# 2020-01-25  1001.0  Autauga  Alabama  32.539527 -86.644082  2020-01-25      0
# 2020-01-26  1001.0  Autauga  Alabama  32.539527 -86.644082  2020-01-26      0
#
#            state_code  deaths  day  month  year
# date
# 2020-01-22         AL       0   22      1  2020
# 2020-01-23         AL       0   23      1  2020
# 2020-01-24         AL       0   24      1  2020
# 2020-01-25         AL       0   25      1  2020
# 2020-01-26         AL       0   26      1  2020

# %%
States_df=covid_df.loc[(covid_df["state"]=="Florida")|(covid_df["state"]=="Indiana")|(covid_df["state"]=="Wisconsin")|(covid_df["state"]=="Louisiana")]
cases=States_df.groupby(["year","month","state"]).max()["cases"]

unimpacted_states=pd.DataFrame({
                            "Infection Rate":cases,
                            }).reset_index()
unimpacted_states.drop(unimpacted_states[unimpacted_states['year'] == 2021].index, inplace = True)
unimpacted_states["month"].replace({1: "January",2: "February",3:"March",4:"April",5:"May",6:"June",7:"July",8:"August",9:"September",10:"October",11:"November",12:"December"}, inplace=True)

unimpacted_states
# Out:
#     year      month      state  Infection Rate
# 0   2020    January    Florida               0
# 1   2020    January    Indiana               0
# 2   2020    January  Louisiana               0
# 3   2020    January  Wisconsin               0
# 4   2020   February    Florida               0
# 5   2020   February    Indiana               0
# 6   2020   February  Louisiana               0
# 7   2020   February  Wisconsin               0
# 8   2020      March    Florida            2123
# 9   2020      March    Indiana             964
# 10  2020      March  Louisiana            1834
# 11  2020      March  Wisconsin             710
# 12  2020      April    Florida           12063
# 13  2020      April    Indiana            5530
# 14  2020      April  Louisiana            6452
# 15  2020      April  Wisconsin            2940
# 16  2020        May    Florida           18000
# 17  2020        May    Indiana            9853
# 18  2020        May  Louisiana            7584
# 19  2020        May  Wisconsin            7750
# 20  2020       June    Florida           36820
# 21  2020       June    Indiana           11329
# 22  2020       June  Louisiana            9489
# 23  2020       June  Wisconsin           11358
# 24  2020       July    Florida          118462
# 25  2020       July    Indiana           14432
# 26  2020       July  Louisiana           14155
# 27  2020       July  Wisconsin           19248
# 28  2020     August    Florida          156910
# 29  2020     August    Indiana           18466
# 30  2020     August  Louisiana           16461
# 31  2020     August  Wisconsin           24079
# 32  2020  September    Florida          170400
# 33  2020  September    Indiana           21671
# 34  2020  September  Louisiana           17633
# 35  2020  September  Wisconsin           29149
# 36  2020    October    Florida          185891
# 37  2020    October    Indiana           27455
# 38  2020    October  Louisiana           18785
# 39  2020    October  Wisconsin           45652
# 40  2020   November    Florida          229618
# 41  2020   November    Indiana           46131
# 42  2020   November  Louisiana           22609
# 43  2020   November  Wisconsin           73097
# 44  2020   December    Florida          298873
# 45  2020   December    Indiana           70610
# 46  2020   December  Louisiana           31498
# 47  2020   December  Wisconsin           91624

# %%
Florida_df=unimpacted_states.loc[(unimpacted_states["state"]=="Florida")]
Louisiana_df=unimpacted_states.loc[(unimpacted_states["state"]=="Louisiana")]
Wisconsin_df=unimpacted_states.loc[(unimpacted_states["state"]=="Wisconsin")]
Indiana_df=unimpacted_states.loc[(unimpacted_states["state"]=="Indiana")]

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True,figsize=(15,15))
fig.tight_layout()

fig.suptitle("Covid=19 infection trend", fontsize=16, fontweight="bold")
plt.xticks(rotation=90)

ax1.plot(Florida_df['month'],Florida_df['Infection Rate'], linewidth=1, marker="o")
ax1.ticklabel_format(style='plain', useOffset=False, axis='y')
ax1.set_title("Florida")

ax2.plot(Louisiana_df["month"], Louisiana_df['Infection Rate'], linewidth=1, marker="o", color="r")
ax2.ticklabel_format(style='plain', useOffset=False, axis='y')
ax2.set_title("Louisiana")

ax3.plot( Wisconsin_df["month"], Wisconsin_df['Infection Rate'], linewidth=1, marker="o", color="g")
ax3.ticklabel_format(style='plain', useOffset=False, axis='y')
ax3.set_title("Wisconsin")

ax4.plot(Indiana_df["month"], Indiana_df['Infection Rate'], linewidth=1, marker="o", color="y")
ax4.ticklabel_format(style='plain', useOffset=False, axis='y')
ax4.set_ylabel("Month if the year 2020")
ax4.set_xlabel("Covid-19 Infection rate in each state")
ax4.set_title("Indiana")
plt.savefig("../Visualizations/Unimpacted_cities_covid_trend.png")
plt.show()

# %%
plt.figure(num=None, figsize=(15,15), dpi=None, facecolor=None, edgecolor=None, frameon=True, clear=False).tight_layout()
merge_df.plot(x="state", y="Infection Rate" ,kind="bar",)
plt.xlabel('state')
plt.ylabel('covid rate')
plt.show()

# %%
# top 10 cities
plt.figure ()
Ten_top.plot(x="state", y="Infection Rate" ,kind="bar",)
plt.xlabel('State')
plt.ylabel('Number of Positive covid tests in 2020')


plt.savefig("../Visualizations/top_10_States_covid_Infection.png")
